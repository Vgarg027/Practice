# %% [markdown]
# # TMDb movie data

# %% [markdown]
# ## Introduction
# This data set contains information
# about 10,000 movies collected from
# The Movie Database (TMDb),
# including user ratings and revenue.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Reading the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('movies.csv')

# %%
##understand the features in the dataset
##identify the dependent variables and independent variables

# %% [markdown]
# ### Data Assessing

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# ### There are null values which we need to drop them or we can use fillna function but it depends on the case

# %% [markdown]
# ### Data Cleaning

# %%
df.dropna(inplace=True)

# %%
**make sure that the null values are dropped**

# %%
df.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %%
** imdb_id colum has combined valaue string and integer example (tt928928)**

# %%
df["imdb_id"]=df["imdb_id"].str.extract('(\d+)').astype(int)

# %%
df["imdb_id"]
# Out:
# 0         369610
# 1        1392190
# 2        2908446
# 3        2488496
# 4        2820852
#           ...
# 10724      64757
# 10759      77651
# 10760      77975
# 10817      77838
# 10819      77696
# Name: imdb_id, Length: 1992, dtype: int32

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10724    False
# 10759    False
# 10760    False
# 10817    False
# 10819    False
# Length: 1992, dtype: bool

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Exploration(1D)

# %%
df.hist();

# %%
df["budget"].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
df_years = df.groupby('release_year').count()['director']
df_years.plot(kind='bar', rot=90)
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
# x axis i added rot param to fix it but it appears like this but we can found here 2010 and 2011 got the largest numbers of moveis

# %% [markdown]
# ### Bivariate Exploration(2D)

# %%
# scatter plot for two numeric variables, box plot for one numeric and one categorical, clustered bar chart for two categorical

# %%
X = df['budget'].index
y = df['revenue'].values
plt.bar(X,y);
plt.xticks(rotation=90);

# %% [markdown]
# ## Question1

# %%
## what is the most genres of the movies ?
here we found that drama and comedy have the biggest part of movies production

# %%
df['genres'].value_counts().plot(kind='pie', rot = 45)
# Out:
# <AxesSubplot:ylabel='genres'>

# %% [markdown]
# ## Question2
# ### here i tried to answer the question which movie get the highest revenue

# %%
X2 = df['original_title'].values
y2=df['revenue'].index
plt.bar(X2,y2);
plt.xticks(rotation = 90);
