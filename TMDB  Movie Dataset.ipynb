# %%
# importing packages which i need to solve this project
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # introduction
# This data set contains information
# about 10,000 movies collected from
# The Movie Database (TMDb),
# including user ratings and revenue.
# ● Certain columns, like ‘cast’
# and ‘genres’, contain multiple
# values separated by pipe (|)
# characters.
# ● There are some odd characters
# in the ‘cast’ column. Don’t worry
# about cleaning them. You can
# leave them as is.
# ● The final two columns ending
# with “_adj” show the budget and
# revenue of the associated movie
# in terms of 2010 dollars,
# accounting for inflation over time

# %% [markdown]
# #  Questions
#
# What the Most producing titles years  ?
# What the Most popularity film ?
# What the most duration film
# What the high budget , revenue ,  voting ,  budget_adj

# %% [markdown]
# # Loading and wrangling data set

# %%
df = pd.read_csv(r'C:\Users\lap\Desktop\tmdb-movies.csv')
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# # Exploring data

# %%
# what is data types
df.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# dtype: object

# %%
# Exploring shape of data
df.shape
# Out:
# (10866, 21)

# %%
# Exploring size of data
df.size
# Out:
# 228186

# %%
# what the names of columns 
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
# information about data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
# counting of data 
df.count()
# Out:
# id                      10866
# imdb_id                 10856
# popularity              10866
# budget                  10866
# revenue                 10866
# original_title          10866
# cast                    10790
# homepage                 2936
# director                10822
# tagline                  8042
# keywords                 9373
# overview                10862
# runtime                 10866
# genres                  10843
# production_companies     9836
# release_date            10866
# vote_count              10866
# vote_average            10866
# release_year            10866
# budget_adj              10866
# revenue_adj             10866
# dtype: int64

# %%
# some statistical informations about data
df.describe().round(1)
# Out:
#              id  popularity       budget       revenue  runtime  vote_count  \
# count   10866.0     10866.0      10866.0  1.086600e+04  10866.0     10866.0
# mean    66064.2         0.6   14625701.1  3.982332e+07    102.1       217.4
# std     92130.1         1.0   30913213.8  1.170035e+08     31.4       575.6
# min         5.0         0.0          0.0  0.000000e+00      0.0        10.0
# 25%     10596.2         0.2          0.0  0.000000e+00     90.0        17.0
# 50%     20669.0         0.4          0.0  0.000000e+00     99.0        38.0
# 75%     75610.0         0.7   15000000.0  2.400000e+07    111.0       145.8
# max    417859.0        33.0  425000000.0  2.781506e+09    900.0      9767.0
#
#        vote_average  release_year   budget_adj   revenue_adj
# count       10866.0       10866.0      10866.0  1.086600e+04
# mean            6.0        2001.3   17551039.8  5.136436e+07
# std             0.9          12.8   34306155.7  1.446325e+08
# ...

# %% [markdown]
# # Data Cleaning

# %%
# finding duplicate values
df.duplicated().sum()
# Out:
# 1

# %%
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
# finding null values
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# visulization of null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# find null values in data sets and sort it descending
df.isnull().sum().sort_values(ascending = False)
# Out:
# homepage                7930
# tagline                 2824
# keywords                1493
# production_companies    1030
# cast                      76
# director                  44
# genres                    23
# imdb_id                   10
# overview                   4
# budget_adj                 0
# release_year               0
# vote_average               0
# vote_count                 0
# release_date               0
# id                         0
# runtime                    0
# original_title             0
# revenue                    0
# budget                     0
# popularity                 0
# revenue_adj                0
# dtype: int64

# %%
#dropping unusul columns from dataframe
df.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
# rename some columns in data frame
df.rename(columns = {'runtime':'duration'},inplace = True)
df.rename(columns = {'original_title':'Title'},inplace = True)
df.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                           Title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue               Title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
# deleting duplicates values from dataframe
df.drop_duplicates(['keywords','id','popularity','budget','revenue','Title','cast','director','overview','duration','genres', 'production_companies' , 'release_date' , 'vote_count' , 'vote_average' , 'release_year' ,'budget_adj', 'revenue_adj'],inplace = True)

# %%
# data shape after deleting duplicates values from dataframe   
df.shape
# Out:
# (10865, 21)

# %%
# remove some columns contain null values
df.drop({'imdb_id','homepage','tagline','keywords'},axis = 1, inplace = True)
df
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10861      21    0.080598          0           0
# 10862   20379    0.065543          0           0
# 10863   39768    0.065141          0           0
# 10864   21449    0.064317          0           0
# 10865   22293    0.035919      19000           0
#
#                               Title  duration release_date  vote_count  \
# 0                    Jurassic World       124       6/9/15        5562
# 1                Mad Max: Fury Road       120      5/13/15        6185
# 2                         Insurgent       119      3/18/15        2480
# 3      Star Wars: The Force Awakens       136     12/15/15        5292
# ...

# %%
df.head(2)
# Out:
#        id  popularity     budget     revenue               Title  duration  \
# 0  135397   32.985763  150000000  1513528810      Jurassic World       124
# 1   76341   28.419936  150000000   378436354  Mad Max: Fury Road       120
#
#   release_date  vote_count  vote_average  release_year    budget_adj  \
# 0       6/9/15        5562           6.5          2015  1.379999e+08
# 1      5/13/15        6185           7.1          2015  1.379999e+08
#
#     revenue_adj
# 0  1.392446e+09
# 1  3.481613e+08

# %%
# data frame clean from null values
df.isnull().sum()
# Out:
# id              0
# popularity      0
# budget          0
# revenue         0
# Title           0
# duration        0
# release_date    0
# vote_count      0
# vote_average    0
# release_year    0
# budget_adj      0
# revenue_adj     0
# dtype: int64

# %% [markdown]
# # Data analysis

# %%
# histogram of dataframe 
df.hist(figsize=(16,6.5));

# %%
# sample of dataframe 
df.sample(7)
# Out:
#            id  popularity    budget   revenue  \
# 2206    44219    0.307351         0         0
# 1833   282963    0.143953         0         0
# 774    284689    0.956582         0   1822250
# 6172    13938    0.592905  10000000  25754284
# 1596    45098    0.454896         0         0
# 10308   12519    0.449066         0   7770731
# 7921      655    0.518436   1746964   2181987
#
#                                  Title  duration release_date  vote_count  \
# 2206                    The Chosen One       101       9/3/10          10
# 1833    Doctor Who: Planet of the Dead        59      7/26/09          22
# 774                 Testament of Youth       129     10/14/14         151
# 6172                   The Last Dragon       108      3/22/85          31
# 1596   Seulpeumboda deo seulpeun Iyagi       105      3/11/09          13
# 10308                           Sirens        98      10/1/93          15
# 7921                      Paris, Texas       147      5/19/84         146
# ...

# %%
# revenue in different years 
df2 =df.groupby('release_year')[['revenue']].sum()

# %%
df2
# Out:
#                   revenue
# release_year
# 1960            145005000
# 1961            337720188
# 1962            215579846
# 1963            187404989
# 1964            340981782
# 1965            458081854
# 1966             84736689
# 1967            737834637
# 1968            264732980
# 1969            243957076
# 1970            560221969
# 1971            404910610
# 1972            494730171
# 1973           1223981102
# 1974            812539818
# 1975            957489966
# 1976            801005600
# 1977           2180583159
# 1978           1369779659
# 1979           1684794913
# 1980           1768662387
# 1981           1774606236
# 1982           2458443852
# 1983           2307529320
# 1984           2635524418
# 1985           2875772392
# 1986           3002778281
# 1987           3462104847
# 1988           3739550845
# 1989           5164923718
# 1990           5315166660
# 1991           4706599796
# 1992           6078153217
# 1993           6955151167
# ...

# %%
# top titles revenues 
top_10_revenue = df2.sort_values(['revenue'],ascending = False).head(10)

# %%
top_10_revenue.hist(figsize=(16,6.5));

# %%
top_10_revenue.sort_values(['revenue'] , ascending = False).plot()
# Out:
# <AxesSubplot:xlabel='release_year'>

# %%
df.head(2)
# Out:
#        id  popularity     budget     revenue               Title  duration  \
# 0  135397   32.985763  150000000  1513528810      Jurassic World       124
# 1   76341   28.419936  150000000   378436354  Mad Max: Fury Road       120
#
#   release_date  vote_count  vote_average  release_year    budget_adj  \
# 0       6/9/15        5562           6.5          2015  1.379999e+08
# 1      5/13/15        6185           7.1          2015  1.379999e+08
#
#     revenue_adj
# 0  1.392446e+09
# 1  3.481613e+08

# %%
# top budget 
df.sort_values(['budget'] , ascending = False).head(10)
# Out:
#          id  popularity     budget     revenue  \
# 2244  46528    0.250540  425000000    11087569
# 3375   1865    4.955130  380000000  1021683000
# 7387    285    4.965391  300000000   961000000
# 14    99861    5.944927  280000000  1405035767
# 6570   1452    1.957331  270000000   391081192
# 4411  49529    1.588457  260000000   284139100
# 1929  38757    2.865684  260000000   591794936
# 7394    559    2.520912  258000000   890871626
# 5508  57201    1.214510  255000000    89289910
# 4367  49051    4.218933  250000000  1017003568
#
#                                             Title  duration release_date  \
# 2244                            The Warrior's Way       100      12/2/10
# 3375  Pirates of the Caribbean: On Stranger Tides       136      5/11/11
# 7387     Pirates of the Caribbean: At World's End       169      5/19/07
# 14                        Avengers: Age of Ultron       141      4/22/15
# 6570                             Superman Returns       154      6/28/06
# ...

# %%
# statistical duration of release_year
grouped_movies = df['duration'].groupby(df['release_year']).describe().round(1)

# %%
grouped_movies.head(10)
# Out:
#               count   mean   std   min   25%    50%    75%    max
# release_year
# 1960           32.0  110.7  33.5  70.0  85.8  103.5  126.2  208.0
# 1961           31.0  119.4  28.2  79.0  99.0  110.0  135.0  186.0
# 1962           32.0  124.3  36.3  78.0  97.0  117.5  145.0  216.0
# 1963           34.0  111.3  37.2  18.0  89.0  108.5  125.0  248.0
# 1964           42.0  109.2  26.2  28.0  93.0  110.5  124.5  170.0
# 1965           35.0  118.2  34.9  25.0  97.5  112.0  134.5  199.0
# 1966           46.0  106.9  32.3  25.0  93.2  106.5  122.5  182.0
# 1967           40.0  105.0  26.1   4.0  92.0  107.0  117.8  152.0
# 1968           39.0  107.3  34.9   4.0  95.5  107.0  132.0  155.0
# 1969           31.0  106.6  33.2   2.0  91.0  105.0  128.5  158.0

# %%
df.head(5)
# Out:
#        id  popularity     budget     revenue                         Title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#    duration release_date  vote_count  vote_average  release_year  \
# 0       124       6/9/15        5562           6.5          2015
# 1       120      5/13/15        6185           7.1          2015
# 2       119      3/18/15        2480           6.3          2015
# 3       136     12/15/15        5292           7.5          2015
# 4       137       4/1/15        2947           7.3          2015
#
#      budget_adj   revenue_adj
# 0  1.379999e+08  1.392446e+09
# 1  1.379999e+08  3.481613e+08
# ...

# %%
# sample of titles in 2015 
df[df.release_year == 2015].sample(10)
# Out:
#          id  popularity     budget    revenue  \
# 303  323660    0.404511          0          0
# 91   274167    1.904898   50000000  240360392
# 553  371759    0.068741          0          0
# 273  323027    0.452939          0          0
# 287  266639    0.435582    5000000    2333684
# 46   228161    2.976436  135000000  368871007
# 494  361671    0.129455          0          0
# 362  328869    0.324515          0          0
# 393  343284    0.283194    2000000          0
# 584  321039    0.190385          0          0
#
#                                       Title  duration release_date  \
# 303                          Avengers Grimm        90      3/17/15
# 91                             Daddy's Home        96     12/25/15
# 553  Doctor Who: The Husbands of River Song        60     12/25/15
# 273       Justice League: Gods and Monsters        76      7/28/15
# 287                   Jem and the Holograms       119     10/22/15
# ...

# %%
# data if duration > 80 and release_year == 2014
df[(df.duration > 80) & (df.release_year == 2014)].head(20)
# Out:
#          id  popularity     budget    revenue  \
# 629  157336   24.949134  165000000  621752480
# 630  118340   14.311205  170000000  773312399
# 631  100402   12.971027  170000000  714766572
# 632  245891   11.422751   20000000   78739897
# 633  131631   10.739009  125000000  752100229
# 634  122917   10.174599  250000000  955119788
# 635  177572    8.691294  165000000  652105443
# 636  205596    8.110711   14000000  233555708
# 637  198663    7.137273   34000000  348319861
# 638  194662    6.907148   18000000  103215094
# 639  210577    6.438727   61000000  369330363
# 640  228150    6.415818   68000000  211817906
# 641  181533    6.286692  127000000  349424282
# 642  157350    6.145020   85000000  288747895
# 643  127585    6.052479  250000000  746000000
# 644  240832    5.947136   40000000  463360063
# 645   98566    5.787396  125000000  477200000
# 646  225886    5.701683   40000000  126069509
# 647  242582    5.522641    8500000   38697217
# ...

# %%
# searching for Interstellar film 
df[df.Title=='Interstellar']
# Out:
#          id  popularity     budget    revenue         Title  duration  \
# 629  157336   24.949134  165000000  621752480  Interstellar       169
#
#     release_date  vote_count  vote_average  release_year    budget_adj  \
# 629      11/5/14        6498           8.0          2014  1.519800e+08
#
#       revenue_adj
# 629  5.726906e+08

# %%
# revenue of X-Men: Days of Future Past film
df[df.Title=='X-Men: Days of Future Past'].revenue.sum()
# Out:
# 746000000

# %%
# looking for data in range 100:115
df.iloc[100:115]
# Out:
#          id  popularity    budget   revenue  \
# 100  326359    1.724712         0         0
# 101  254302    1.661789         0         0
# 102  241251    1.651078   4000000  50163103
# 103  292040    1.646664         0         0
# 104  188222    1.532997  30000000  49263404
# 105  252838    1.510096  23000000  79799880
# 106  273477    1.499614  15000000  14860766
# 107  298312    1.495112   5000000  98450062
# 108  261023    1.483246  53000000  99775678
# 109  336004    1.449072   8900000     50136
# 110  287903    1.448002  15000000  61548707
# 111  182560    1.443406  20000000    208588
# 112  192141    1.412390   5000000  54418872
# 113  308639    1.408050    700000  17986781
# 114  261392    1.388251  28000000  28208085
#
#                                      Title  duration release_date  vote_count  \
# 100                           Frozen Fever         8       3/9/15         475
# 101                              High-Rise       119      9/26/15         161
# ...

# %%
# looking for some of titles in dataframe
df[df['Title'].isin(['Birdman','American Ultra','Avengers Grimm','Captain America: The Winter Soldier','Jurassic World','Interstellar'])]
# Out:
#          id  popularity     budget     revenue  \
# 0    135397   32.985763  150000000  1513528810
# 114  261392    1.388251   28000000    28208085
# 303  323660    0.404511          0           0
# 629  157336   24.949134  165000000   621752480
# 631  100402   12.971027  170000000   714766572
# 638  194662    6.907148   18000000   103215094
#
#                                    Title  duration release_date  vote_count  \
# 0                         Jurassic World       124       6/9/15        5562
# 114                       American Ultra        96      8/19/15         695
# 303                       Avengers Grimm        90      3/17/15          23
# 629                         Interstellar       169      11/5/14        6498
# 631  Captain America: The Winter Soldier       136      3/20/14        3848
# 638                              Birdman       119     10/17/14        2801
#
#      vote_average  release_year    budget_adj   revenue_adj
# ...

# %%
# the high budget in dataframe
df['budget'].max()
# Out:
# 425000000

# %%
# the loW budget in dataframe
df['budget'].min()
# Out:
# 0

# %%
#  the high revenue in dataframe
df['revenue'].max()
# Out:
# 2781505847

# %%
# statistical revenue
df['revenue'].describe().round(1)
# Out:
# count    1.086500e+04
# mean     3.982690e+07
# std      1.170083e+08
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.400000e+07
# max      2.781506e+09
# Name: revenue, dtype: float64

# %%
# statistical duration
df['duration'].describe().round(1)
# Out:
# count    10865.0
# mean       102.1
# std         31.4
# min          0.0
# 25%         90.0
# 50%         99.0
# 75%        111.0
# max        900.0
# Name: duration, dtype: float64

# %%
df.head(2)
# Out:
#        id  popularity     budget     revenue               Title  duration  \
# 0  135397   32.985763  150000000  1513528810      Jurassic World       124
# 1   76341   28.419936  150000000   378436354  Mad Max: Fury Road       120
#
#   release_date  vote_count  vote_average  release_year    budget_adj  \
# 0       6/9/15        5562           6.5          2015  1.379999e+08
# 1      5/13/15        6185           7.1          2015  1.379999e+08
#
#     revenue_adj
# 0  1.392446e+09
# 1  3.481613e+08

# %%
# sorting values of high duration title
duration_title = df[['Title','duration']]

# %%
duration_title.sort_values(['duration'],ascending= False).head(10)
# Out:
#                               Title  duration
# 3894  The Story of Film: An Odyssey       900
# 4041                          Taken       877
# 2722               Band of Brothers       705
# 6176                          Shoah       566
# 6181        North and South, Book I       561
# 6894                   Planet Earth       550
# 2214                    The Pacific       540
# 3356                     John Adams       501
# 1865                           Life       500
# 3141                Generation Kill       470

# %%
duration_title.hist(figsize=(16,6.5));

# %%
df.head(2)
# Out:
#        id  popularity     budget     revenue               Title  duration  \
# 0  135397   32.985763  150000000  1513528810      Jurassic World       124
# 1   76341   28.419936  150000000   378436354  Mad Max: Fury Road       120
#
#   release_date  vote_count  vote_average  release_year    budget_adj  \
# 0       6/9/15        5562           6.5          2015  1.379999e+08
# 1      5/13/15        6185           7.1          2015  1.379999e+08
#
#     revenue_adj
# 0  1.392446e+09
# 1  3.481613e+08

# %%
# sorting values of high voting title
voting = df[['Title','vote_average']]

# %%
voting.sort_values(['vote_average'],ascending= False).head(10)
# Out:
#                                                   Title  vote_average
# 3894                      The Story of Film: An Odyssey           9.2
# 538                                The Mask You Live In           8.9
# 1200                      Black Mirror: White Christmas           8.8
# 2269                                        Life Cycles           8.8
# 6911                                  Pink Floyd: Pulse           8.7
# 2401    Opeth: In Live Concert At The Royal Albert Hall           8.6
# 3690                                  The Art of Flight           8.5
# 8411                              Queen - Rock Montreal           8.5
# 8221  A Personal Journey with Martin Scorsese Throug...           8.5
# 8839                Dave Chappelle: Killin' Them Softly           8.5

# %%
# sorting values of high budget title
budget = df[['Title','budget_adj']]

# %%
budget.sort_values(['budget_adj'],ascending= False).head(10)
# Out:
#                                             Title    budget_adj
# 2244                            The Warrior's Way  4.250000e+08
# 3375  Pirates of the Caribbean: On Stranger Tides  3.683713e+08
# 7387     Pirates of the Caribbean: At World's End  3.155006e+08
# 6570                             Superman Returns  2.920507e+08
# 5231                                      Titanic  2.716921e+08
# 7394                                 Spider-Man 3  2.713305e+08
# 1929                                      Tangled  2.600000e+08
# 14                        Avengers: Age of Ultron  2.575999e+08
# 1389       Harry Potter and the Half-Blood Prince  2.541001e+08
# 8089                                   Waterworld  2.504192e+08

# %%
# sorting values of high population title
population = df[['Title','popularity']]

# %%
population.sort_values(['popularity'],ascending= False).head(10)
# Out:
#                                       Title  popularity
# 0                            Jurassic World   32.985763
# 1                        Mad Max: Fury Road   28.419936
# 629                            Interstellar   24.949134
# 630                 Guardians of the Galaxy   14.311205
# 2                                 Insurgent   13.112507
# 631     Captain America: The Winter Soldier   12.971027
# 1329                              Star Wars   12.037933
# 632                               John Wick   11.422751
# 3              Star Wars: The Force Awakens   11.173104
# 633   The Hunger Games: Mockingjay - Part 1   10.739009

# %%
# searching by first letter if letter is B
df[df.Title.str.startswith('B')].head(10)
# Out:
#          id  popularity    budget    revenue                     Title  \
# 33   296098    3.648210  40000000  162610473           Bridge of Spies
# 39   167073    3.227329  11000000   62076141                  Brooklyn
# 55   295964    2.584264  20000000   36606743                     Burnt
# 59   201088    2.550747  70000000   17752940                  Blackhat
# 72   284289    2.272044         0      45895          Beyond the Reach
# 108  261023    1.483246  53000000   99775678                Black Mass
# 143  378373    1.128081         0          0      Brothers of the Wind
# 145  294963    1.073349   1800000          0             Bone Tomahawk
# 171  248574    0.880268         0       6075             Barely Lethal
# 198  316322    0.714131         0          0  Barbie in Princess Power
#
#      duration release_date  vote_count  vote_average  release_year  \
# 33        141     10/15/15        1638           7.1          2015
# ...

# %%
# searching by last letter if letter is e  
df[df.Title.str.endswith('e')].head(10)
# Out:
#         id  popularity     budget    revenue                         Title  \
# 10  206647    6.200282  245000000  880674609                       Spectre
# 27  207703    4.503789   81000000  403802136  Kingsman: The Secret Service
# 31  198184    3.899557   49000000  102069268                       Chappie
# 36  339527    3.358321          0   22354572                        Solace
# 44  293863    3.025852   25000000   42629776            The Age of Adaline
# 46  228161    2.976436  135000000  368871007                          Home
# 74  347096    2.165433          0          0        Mythica: The Darkspore
# 76  227973    2.140199   99000000  246233113             The Peanuts Movie
# 78  296100    2.096273   25000000   52395996              The Night Before
# 80  228205    2.070708   34000000   63013281              The Longest Ride
#
#     duration release_date  vote_count  vote_average  release_year  \
# 10       148     10/26/15        3254           6.2          2015
# ...

# %%
# looking for first 14 roWs
df.iloc[:14]
# Out:
#         id  popularity     budget     revenue                         Title  \
# 0   135397   32.985763  150000000  1513528810                Jurassic World
# 1    76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   262500   13.112507  110000000   295238201                     Insurgent
# 3   140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4   168259    9.335014  190000000  1506249360                     Furious 7
# 5   281957    9.110700  135000000   532950503                  The Revenant
# 6    87101    8.654359  155000000   440603537            Terminator Genisys
# 7   286217    7.667400  108000000   595380321                   The Martian
# 8   211672    7.404165   74000000  1156730962                       Minions
# 9   150540    6.326804  175000000   853708609                    Inside Out
# 10  206647    6.200282  245000000   880674609                       Spectre
# ...

# %%
# counting top years produced titles
no_title = df.groupby('release_year')[['Title']].count()

# %%
no_title.sort_values(['Title'],ascending= False).head(10)
# Out:
#               Title
# release_year
# 2014            700
# 2013            659
# 2015            629
# 2012            588
# 2011            540
# 2009            533
# 2008            496
# 2010            489
# 2007            438
# 2006            408

# %%
no_title.hist(figsize=(14,5.5));

# %%
no_title.describe().round(1).plot()
# Out:
# <AxesSubplot:>

# %%
# counting less years produced titles
no_title2 = df.groupby('release_year')[['Title']].count()

# %%
no_title2.sort_values(['Title'],ascending= True).head(10)
# Out:
#               Title
# release_year
# 1961             31
# 1969             31
# 1960             32
# 1962             32
# 1963             34
# 1965             35
# 1968             39
# 1967             40
# 1972             40
# 1970             41

# %%
no_title2.describe().round(1).plot()
# Out:
# <AxesSubplot:>

# %%
no_Titles['Title'].plot()
plt.xlabel = 'release_year'
plt.ylabel = 'Title'
plt.title('total Titles in years ')
# Out:
# Text(0.5, 1.0, 'total Titles in years ')

# %%
# sorting voting and duration 
df[(df.vote_count > 4500) & (df.duration > 120)].head(10)
# Out:
#           id  popularity     budget     revenue                         Title  \
# 0     135397   32.985763  150000000  1513528810                Jurassic World
# 3     140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 7     286217    7.667400  108000000   595380321                   The Martian
# 629   157336   24.949134  165000000   621752480                  Interstellar
# 630   118340   14.311205  170000000   773312399       Guardians of the Galaxy
# 1386   19995    9.432768  237000000  2781505847                        Avatar
# 1919   27205    9.363643  160000000   825500000                     Inception
# 1920   10138    5.704860  200000000   623933331                    Iron Man 2
# 2409     550    8.947905   63000000   100853753                    Fight Club
# 2410     603    7.753899   63000000   463517383                    The Matrix
#
#       duration release_date  vote_count  vote_average  release_year  \
# ...

# %%
df['id'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Conclusions
# * I used some analysis tool in this project and my Conclusions is
#  1 - the high year films produced is 2014
#  2 - the most popularity film is Jurassic World
#  3 - the most duration film is The Story of Film: An Odyssey
#  4 - the high budget 425000000
#  5 - the high revenue 2781505847
#  6 - the high voting is The Story of Film: An Odyssey 	9.2
#  7 - high budget_adj is The Warrior's Way 	4.250000e+08

# %% [markdown]
# #  Limitation
#
# no clear information betWeen adj” show the budget and
# revenue of the associated movie
