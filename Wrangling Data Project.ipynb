# %% [markdown]
# ## WeRateDogs Twitter Archieve Data
#
# ### project description
# The dataset that I will be wrangling, analyzing, and visualizing is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because "they're good dogs Brent." WeRateDogs has over 4 million followers and has received international media coverage.
#
#
# #### Project Steps Overview
#
# Step 1: Gathering data
#
# Step 2: Assessing data
#
# Step 3: Cleaning data
#
# Step 4: Storing data
#
# Step 5: Analyzing, and visualizing data
#
# Step 6: Reporting
#
#    - data wrangling efforts
#    - data analyses and visualizations

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer
import requests
import os

# %matplotlib inline

# %%
! ls
# Out:
# Untitled.ipynb
# Untitled1.ipynb
# Wrangling Data Project - Jupyter Notebook.pdf
# Wrangling Data Project.ipynb
# image-predictions.tsv
# tweet-json copy
# tweet-json.json
# tweet_json.txt
# tweets_data
# twitter-api.rtf
# twitter-archive-enhanced.csv
# venv
# ~$itter-api.rtf

# %% [markdown]
# ### Project Motivation
# wrangle WeRateDogs Twitter data to create interesting and trustworthy analyses and visualizations. The Twitter archive is great, but it only contains very basic tweet information. Additional gathering, then assessing and cleaning is required for "Wow!"-worthy analyses and visualizations.

# %% [markdown]
# # Gather Data

# %% [markdown]
# - I have Downloaded "twitter-archive-enhanced.csv", uploaded it using pandas
# - I have Downloaded "image-predictions.tsv" programmatically using the link provided
# - I have queried Twitter API using Tweepy lib, saved the data in a file called "Tweets-json.txt", and uploaded the data of the "Tweets-json.txt" inta a DF using pandas

# %%
# upload the data of "tweet-json.json"
tweets = pd.read_csv("twitter-archive-enhanced.csv")

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
tweets.head(10)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
# 5  891087950875897856                    NaN                  NaN
# 6  890971913173991426                    NaN                  NaN
# 7  890729181411237888                    NaN                  NaN
# 8  890609185150312448                    NaN                  NaN
# 9  890240255349198849                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
# 5  2017-07-29 00:08:17 +0000
# 6  2017-07-28 16:27:12 +0000
# 7  2017-07-28 00:22:40 +0000
# 8  2017-07-27 16:25:51 +0000
# 9  2017-07-26 15:59:51 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
# 5  <a href="http://twitter.com/download/iphone" r...
# 6  <a href="http://twitter.com/download/iphone" r...
# 7  <a href="http://twitter.com/download/iphone" r...
# 8  <a href="http://twitter.com/download/iphone" r...
# 9  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
# 5  Here we have a majestic great white breaching ...                  NaN
# 6  Meet Jax. He enjoys ice cream so much he gets ...                  NaN
# 7  When you watch your owner call another dog a g...                  NaN
# 8  This is Zoey. She doesn't want to be one of th...                  NaN
# 9  This is Cassie. She is a college pup. Studying...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# 5                       NaN                        NaN
# 6                       NaN                        NaN
# 7                       NaN                        NaN
# 8                       NaN                        NaN
# 9                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
# 5  https://twitter.com/dog_rates/status/891087950...                13
# 6  https://gofundme.com/ydvmve-surgery-for-jax,ht...                13
# 7  https://twitter.com/dog_rates/status/890729181...                13
# 8  https://twitter.com/dog_rates/status/890609185...                13
# 9  https://twitter.com/dog_rates/status/890240255...                14
#
#    rating_denominator      name  doggo floofer pupper puppo
# 0                  10   Phineas   None    None   None  None
# 1                  10     Tilly   None    None   None  None
# 2                  10    Archie   None    None   None  None
# 3                  10     Darla   None    None   None  None
# 4                  10  Franklin   None    None   None  None
# 5                  10      None   None    None   None  None
# 6                  10       Jax   None    None   None  None
# 7                  10      None   None    None   None  None
# 8                  10      Zoey   None    None   None  None
# 9                  10    Cassie  doggo    None   None  None

# %%
# download the data of "image-predictions.tsv" programmatically
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"

# get request to get the file data from the url
r = requests.get(url)

# write the data into a file
with open("image-predictions.tsv", mode = "wb") as file:
    file.write(r.content)

# %%
# !ls
# Out:
# Untitled.ipynb
# Untitled1.ipynb
# Wrangling Data Project - Jupyter Notebook.pdf
# Wrangling Data Project.ipynb
# image-predictions.tsv
# tweet-json copy
# tweet-json.json
# tweet_json.txt
# tweets_data
# twitter-api.rtf
# twitter-archive-enhanced.csv
# venv
# ~$itter-api.rtf

# %%
# upload the data of "image-predictions.tsv"
predictions = pd.read_csv("image-predictions.tsv", delimiter = "\t")

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
predictions.head(10)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5  666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6  666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7  666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8  666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9  666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
# 5        1    Bernese_mountain_dog  0.651137    True    English_springer
# 6        1              box_turtle  0.933012   False          mud_turtle
# 7        1                    chow  0.692517    True     Tibetan_mastiff
# 8        1           shopping_cart  0.962465   False     shopping_basket
# 9        1        miniature_poodle  0.201493    True            komondor
#
#     p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0  0.156665    True            Shetland_sheepdog  0.061428    True
# 1  0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True                   bloodhound  0.116197    True
# 3  0.360687    True           miniature_pinscher  0.222752    True
# 4  0.243682    True                     Doberman  0.154629    True
# 5  0.263788    True   Greater_Swiss_Mountain_dog  0.016199    True
# 6  0.045885   False                     terrapin  0.017885   False
# 7  0.058279    True                     fur_coat  0.054449   False
# 8  0.014594   False             golden_retriever  0.007959    True
# 9  0.192305    True  soft-coated_wheaten_terrier  0.082086    True

# %% [markdown]
# ### Twitter API Data Gathering

# %% [markdown]
# I'll be using Tweepy to query Twitter's API for additional data beyond the data included in the WeRateDogs Twitter archive. This additional data will include retweet count and favorite count.

# %%
# tweepy authentication
consumer_key = 'Hidden'
consumer_secret = 'Hidden'
access_token = 'Hidden'
access_secret = 'Hidden'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
# query the twitter API for each tweet data using tweets IDs
tweets_id = tweets["tweet_id"]

# create a dict to save info about failed quries
failed = {}

# loop over each id query the API, Write data into file
start = timer()
with open("tweets_data", "w") as file:
    file.write("tweet_id,favourite_count,retweet_count\n")
    for tweet_id in tweets_id:
        try:
            # query the API
            tweet = api.get_status(tweet_id, tweet_mode='extended')._json
            
            # get the favourite, and retweet counts
            favourite_count = tweet["favorite_count"]
            retweet_count = tweet["retweet_count"]
            
            # write the favourite, and retweet count onto the file
            file.write("{},{},{}\n".format(tweet_id,favourite_count,retweet_count))
            print("Sucessful Query")
            
        # handling failed queries
        except tweepy.errors.TweepyException as e:
            print("Failed Query")
            failed[ID] = e
            
            pass
    
    end = timer()
    print(end - start)
    
    print(failed)
# Out:
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Sucessful Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# Failed Query
# 1231.2148226000008
# {666020888022790149: TooManyRequests('429 Too Many Requests\n88 - Rate limit exceeded')}

# %%
tweets_api = pd.read_csv("tweets_data")

# %%
tweets_api
# Out:
#                 tweet_id  favourite_count  retweet_count
# 0     892420643555336193            33670           6962
# 1     892177421306343426            29209           5267
# 2     891815181378084864            21958           3463
# 3     891689557279858688            36764           7188
# 4     891327558926688256            35157           7709
# ...                  ...              ...            ...
# 1570  677187300187611136             2476            806
# 1571  676975532580409345             2519            947
# 1572  676957860086095872             2018            719
# 1573  676949632774234114             1177            348
# 1574  676948236477857792             1950            771
#
# [1575 rows x 3 columns]

# %% [markdown]
# # Data Wrangling Process
# ## Assesment

# %% [markdown]
# I will start the wrangling process for the data I have, The data consists of three Dfs
# - tweets from twitter archieve data
# - prediection AI algorithm used to predict the dog breeds
# - tweets_api Data gathered through query twitter API for tweets favourites, and retweets counts

# %% [markdown]
# ### Visual Assessment

# %%
# Visual Assesment of tweets Df
tweets
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %%
predictions
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
tweets_api
# Out:
#                 tweet_id  favourite_count  retweet_count
# 0     892420643555336193            33670           6962
# 1     892177421306343426            29209           5267
# 2     891815181378084864            21958           3463
# 3     891689557279858688            36764           7188
# 4     891327558926688256            35157           7709
# ...                  ...              ...            ...
# 1570  677187300187611136             2476            806
# 1571  676975532580409345             2519            947
# 1572  676957860086095872             2018            719
# 1573  676949632774234114             1177            348
# 1574  676948236477857792             1950            771
#
# [1575 rows x 3 columns]

# %% [markdown]
# ### Programmatic Assessment

# %%
# tweets_df
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
tweets.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 20        2
# 80        2
# 70        1
# 7         1
# 15        1
# 150       1
# 170       1
# 0         1
# 90        1
# 40        1
# 130       1
# 110       1
# 16        1
# 120       1
# 2         1
# Name: rating_denominator, dtype: int64

# %%
tweets.rating_numerator.value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 2         9
# 1         9
# 75        2
# 15        2
# 420       2
# 0         2
# 80        1
# 144       1
# 17        1
# 26        1
# 20        1
# 121       1
# 143       1
# 44        1
# 60        1
# 45        1
# 50        1
# 99        1
# 204       1
# 1776      1
# 165       1
# 666       1
# 27        1
# 182       1
# 24        1
# 960       1
# 84        1
# 88        1
# Name: rating_numerator, dtype: int64

# %%
tweets.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Cooper         11
# Lucy           11
#              ...
# Dex             1
# Ace             1
# Tayzie          1
# Grizzie         1
# Christoper      1
# Name: name, Length: 957, dtype: int64

# %%
tweets.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
# prediction df
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
predictions.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 2065  890240255349198849  https://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 372   672984142909456390  https://pbs.twimg.com/media/CVbrcZyVAAA5Wpq.jpg
# 443   674638615994089473  https://pbs.twimg.com/media/CVzMPh1UsAELQ_p.jpg
# 1851  840370681858686976  https://pbs.twimg.com/media/C6mYrK0UwAANhep.jpg
# 1090  719339463458033665  https://pbs.twimg.com/media/Cfuba6NW4AIeMHk.jpg
# 275   670838202509447168  https://pbs.twimg.com/media/CU9LyIMWIAA6OOu.jpg
# 1967  867900495410671616  https://pbs.twimg.com/media/DAtm5MkXoAA4R6P.jpg
# 1296  752173152931807232  https://pbs.twimg.com/media/CnBBfNuWcAAkOgO.jpg
# 1503  784826020293709826  https://pbs.twimg.com/media/CuRDF-XWcAIZSer.jpg
# 266   670804601705242624  https://pbs.twimg.com/media/CU8tOJZWUAAlNoF.jpg
#
#       img_num                  p1   p1_conf  p1_dog               p2  \
# 2065        1            Pembroke  0.511319    True         Cardigan
# 372         1              wombat  0.738780   False           beaver
# 443         1          Pomeranian  0.846986    True             chow
# 1851        1              teapot  0.981819   False              cup
# 1090        1    golden_retriever  0.765778    True           borzoi
# 275         1            flamingo  0.992710   False     coral_fungus
# 1967        1  Labrador_retriever  0.522644    True           kuvasz
# 1296        1  Labrador_retriever  0.527659    True  German_shepherd
# 1503        1                chow  0.090341    True       binoculars
# 266         1          Pomeranian  0.868560    True         Pekinese
#
#        p2_conf  p2_dog            p3   p3_conf  p3_dog
# 2065  0.451038    True     Chihuahua  0.029248    True
# 372   0.133368   False       wallaby  0.032370   False
# 443   0.142014    True      keeshond  0.002605    True
# 1851  0.014026   False     coffeepot  0.002421   False
# 1090  0.071148    True      Leonberg  0.070371    True
# 275   0.003491   False     stinkhorn  0.001859   False
# 1967  0.332461    True     dalmatian  0.032008    True
# 1296  0.174765    True     Chihuahua  0.045525    True
# 1503  0.083499   False  Irish_setter  0.077456    True
# 266   0.090129    True          chow  0.021722    True

# %%
predictions.img_num.value_counts()
# Out:
# 1    1780
# 2     198
# 3      66
# 4      31
# Name: img_num, dtype: int64

# %%
predictions.p1.value_counts()
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke               89
# Chihuahua              83
# pug                    57
#                      ...
# pillow                  1
# carousel                1
# bald_eagle              1
# lorikeet                1
# orange                  1
# Name: p1, Length: 378, dtype: int64

# %%
predictions.p2.value_counts()
# Out:
# Labrador_retriever    104
# golden_retriever       92
# Cardigan               73
# Chihuahua              44
# Pomeranian             42
#                      ...
# medicine_chest          1
# quail                   1
# horse_cart              1
# waffle_iron             1
# bagel                   1
# Name: p2, Length: 405, dtype: int64

# %%
predictions.p3.value_counts()
# Out:
# Labrador_retriever    79
# Chihuahua             58
# golden_retriever      48
# Eskimo_dog            38
# kelpie                35
#                       ..
# ox                     1
# assault_rifle          1
# axolotl                1
# pot                    1
# banana                 1
# Name: p3, Length: 408, dtype: int64

# %%
# tweets_api Df
tweets_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         1575 non-null   int64
#  1   favourite_count  1575 non-null   int64
#  2   retweet_count    1575 non-null   int64
# dtypes: int64(3)
# memory usage: 37.0 KB

# %%
tweets_api.head()
# Out:
#              tweet_id  favourite_count  retweet_count
# 0  892420643555336193            33670           6962
# 1  892177421306343426            29209           5267
# 2  891815181378084864            21958           3463
# 3  891689557279858688            36764           7188
# 4  891327558926688256            35157           7709

# %%
tweets_api.describe()
# Out:
#            tweet_id  favourite_count  retweet_count
# count  1.575000e+03      1575.000000    1575.000000
# mean   7.626943e+17      8793.850159    2972.690159
# std    6.747285e+16     12250.344855    4636.092860
# min    6.769482e+17         0.000000       1.000000
# 25%    6.990760e+17      2238.000000     792.500000
# 50%    7.472042e+17      4057.000000    1591.000000
# 75%    8.231225e+17     11266.500000    3341.000000
# max    8.924206e+17    144016.000000   70244.000000

# %%
tweets_api.tail()
# Out:
#                 tweet_id  favourite_count  retweet_count
# 1570  677187300187611136             2476            806
# 1571  676975532580409345             2519            947
# 1572  676957860086095872             2018            719
# 1573  676949632774234114             1177            348
# 1574  676948236477857792             1950            771

# %% [markdown]
# ## Assesment Report

# %% [markdown]
# ## Quality Issues
# ##### Tweets DF
# - Miising Data in __[in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp]__ columns
# - In source column the link is extracted with "a" HTML tag
# - __Name__ column, Mistaken values such as [ single character name "a"]
# - Mistaken values in __[rating_denominator, rating_numerator]__ columns
# - erroneous entry Nu: 1970 has p1 value __laptop__
#
#
# ##### Predictions DF
# - columns names of predictions columns are not descriptive __EX/ P1 --> prediction_01__
# - predictions names are not proper cased, have "_" delimiters
# - erroneous prediction values in __P1, P2, and P3__ columns
# - There is missing records in predections DF
#
# ##### Tweets_api  DF
# - Missing Records
#
#
# ## Tidness Issues
# ##### Tweets DF
# - __Dog stages, Dog names__ Columns are in the same DF with Tweets data
# - Columns that are not Necessary for our analysis such as __[in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp]__ Columns
# - data in the columns __[doggo, floofer, pupper, puppo]
#
#
# ##### Predictions DF
# - Data about predictions and Tweets are in the same DFs
# - repeated _tweet_id_ column
#
# ##### Tweets_api  DF
# - repeated __tweet_id__ column

# %% [markdown]
# # Cleaning

# %%
# copying the original Dfs
tweets_clean = tweets.copy()
pred_clean = predictions.copy()
api_clean = tweets_api.copy()

# %% [markdown]
# ### Clean Completness issues

# %%
tweets_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
pred_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
api_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575 entries, 0 to 1574
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         1575 non-null   int64
#  1   favourite_count  1575 non-null   int64
#  2   retweet_count    1575 non-null   int64
# dtypes: int64(3)
# memory usage: 37.0 KB

# %% [markdown]
# ### Define:
# - Drop [in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp] Columns
# - Fill missing data of dog stages

# %% [markdown]
# ### Code

# %%
tweets_clean.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
# drop unrequirred columns
tweets_clean.drop(["in_reply_to_status_id", "in_reply_to_user_id", "retweeted_status_id", "retweeted_status_user_id", "retweeted_status_timestamp", "name", "source"], axis = 1, inplace = True)

# %%
tweets_clean["puppo"].value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
tweets_clean["pupper"].value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
tweets_clean["floofer"].value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
tweets_clean["doggo"].value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
# fill dog stages data
tweets_clean["stage"] = None

for i, row in tweets_clean.iterrows():
    if tweets_clean.loc[i, "text"].find("puppo") != -1: 
        tweets_clean.loc[i,"stage"] = "puppo"
    if tweets_clean.loc[i, "text"].find("pupper") != -1:
        tweets_clean.loc[i,"stage"] = "pupper"
    if tweets_clean.loc[i, "text"].find("floofer") != -1:
        tweets_clean.loc[i,"stage"] = "floofer"
    if tweets_clean.loc[i, "text"].find("doggo") != -1:
        tweets_clean.loc[i,"stage"] = "doggo"

# %% [markdown]
# ### Test

# %%
tweets_clean.isnull().sum()
# Out:
# tweet_id                 0
# timestamp                0
# text                     0
# expanded_urls           59
# rating_numerator         0
# rating_denominator       0
# doggo                    0
# floofer                  0
# pupper                   0
# puppo                    0
# stage                 1957
# dtype: int64

# %%
tweets_clean["stage"].value_counts()
# Out:
# pupper     262
# doggo       98
# puppo       35
# floofer      4
# Name: stage, dtype: int64

# %% [markdown]
# ### Define

# %% [markdown]
# - Drop the Df columns [doggo, puppo, floofer, pupper]

# %% [markdown]
# ### Code

# %%
tweets_clean.drop(["doggo", "floofer", "pupper", "puppo"], axis = 1, inplace = True)

# %%
tweets_clean
# Out:
#                 tweet_id                  timestamp  \
# 0     892420643555336193  2017-08-01 16:23:56 +0000
# 1     892177421306343426  2017-08-01 00:17:27 +0000
# 2     891815181378084864  2017-07-31 00:18:03 +0000
# 3     891689557279858688  2017-07-30 15:58:51 +0000
# 4     891327558926688256  2017-07-29 16:00:24 +0000
# ...                  ...                        ...
# 2351  666049248165822465  2015-11-16 00:24:50 +0000
# 2352  666044226329800704  2015-11-16 00:04:52 +0000
# 2353  666033412701032449  2015-11-15 23:21:54 +0000
# 2354  666029285002620928  2015-11-15 23:05:30 +0000
# 2355  666020888022790149  2015-11-15 22:32:08 +0000
#
#                                                    text  \
# 0     This is Phineas. He's a mystical boy. Only eve...
# 1     This is Tilly. She's just checking pup on you....
# 2     This is Archie. He is a rare Norwegian Pouncin...
# 3     This is Darla. She commenced a snooze mid meal...
# 4     This is Franklin. He would like you to stop ca...
# ...                                                 ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...
# 2352  This is a purebred Piers Morgan. Loves to Netf...
# 2353  Here is a very happy pup. Big fan of well-main...
# 2354  This is a western brown Mitsubishi terrier. Up...
# 2355  Here we have a Japanese Irish Setter. Lost eye...
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator stage
# 0                     10  None
# 1                     10  None
# 2                     10  None
# 3                     10  None
# 4                     10  None
# ...                  ...   ...
# 2351                  10  None
# 2352                  10  None
# 2353                  10  None
# 2354                  10  None
# 2355                  10  None
#
# [2356 rows x 7 columns]

# %% [markdown]
# ### Test

# %%
len(tweets[tweets["doggo"] != "None"]) + len(tweets[tweets["puppo"] != "None"]) + len(tweets[tweets["floofer"] != "None"]) + len(tweets[tweets["pupper"] != "None"])
# Out:
# 394

# %%
tweets_clean["stage"].count()
# Out:
# 399

# %% [markdown]
# ### Define

# %% [markdown]
# Create two tables
# - tweets data
# - dogs and prediction data

# %% [markdown]
# ### Code

# %%
dog_data = tweets_clean.merge(pred_clean, on = "tweet_id", how = "inner")

# %%
dog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2075 non-null   int64
#  1   timestamp           2075 non-null   object
#  2   text                2075 non-null   object
#  3   expanded_urls       2075 non-null   object
#  4   rating_numerator    2075 non-null   int64
#  5   rating_denominator  2075 non-null   int64
#  6   stage               338 non-null    object
#  7   jpg_url             2075 non-null   object
#  8   img_num             2075 non-null   int64
#  9   p1                  2075 non-null   object
#  10  p1_conf             2075 non-null   float64
#  11  p1_dog              2075 non-null   bool
#  12  p2                  2075 non-null   object
#  13  p2_conf             2075 non-null   float64
#  14  p2_dog              2075 non-null   bool
#  15  p3                  2075 non-null   object
#  16  p3_conf             2075 non-null   float64
#  17  p3_dog              2075 non-null   bool
# dtypes: bool(3), float64(3), int64(4), object(8)
# memory usage: 265.5+ KB

# %%
dog_data.drop(["timestamp", "text", "expanded_urls","jpg_url"], axis = 1, inplace  = True)

# %%
tweets_data = tweets_clean.merge(api_clean, on = "tweet_id", how = "inner")

# %%
tweets_data.drop(["rating_numerator", "rating_denominator", "stage"], axis = 1, inplace = True)

# %% [markdown]
# ### Test

# %%
dog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2075 non-null   int64
#  1   rating_numerator    2075 non-null   int64
#  2   rating_denominator  2075 non-null   int64
#  3   stage               338 non-null    object
#  4   img_num             2075 non-null   int64
#  5   p1                  2075 non-null   object
#  6   p1_conf             2075 non-null   float64
#  7   p1_dog              2075 non-null   bool
#  8   p2                  2075 non-null   object
#  9   p2_conf             2075 non-null   float64
#  10  p2_dog              2075 non-null   bool
#  11  p3                  2075 non-null   object
#  12  p3_conf             2075 non-null   float64
#  13  p3_dog              2075 non-null   bool
# dtypes: bool(3), float64(3), int64(4), object(4)
# memory usage: 200.6+ KB

# %%
tweets_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 1574
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         1575 non-null   int64
#  1   timestamp        1575 non-null   object
#  2   text             1575 non-null   object
#  3   expanded_urls    1531 non-null   object
#  4   favourite_count  1575 non-null   int64
#  5   retweet_count    1575 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 86.1+ KB

# %% [markdown]
# ### Define

# %% [markdown]
# - Rename dog_data DF columns names

# %% [markdown]
# ### Code

# %%
dog_data = dog_data.rename(columns = {"p1":"prediction1", "p2":"prediction2", "p3":"prediction3","p1_conf": "prediction1_conf", "p2_conf": "prediction2_conf", "p3_conf": "prediction3_conf", "p1_dog": "prediction1_dog", "p2_dog": "prediction2_dog", "p3_dog": "prediction3_dog"})

# %% [markdown]
# ### Define

# %% [markdown]
# - Make predictions names correct and propper cased

# %% [markdown]
# ### Code

# %%
dog_data["prediction1"] = dog_data["prediction1"].str.replace("_", " ")
dog_data["prediction2"] = dog_data["prediction2"].str.replace("_", " ")
dog_data["prediction3"] = dog_data["prediction3"].str.replace("_", " ")

# %% [markdown]
# ### Test

# %%
dog_data.sample(10)
# Out:
#                 tweet_id  rating_numerator  rating_denominator   stage  \
# 733   758828659922702336                13                  10   doggo
# 731   759047813560868866                11                  10    None
# 951   727175381690781696                10                  10    None
# 1611  674999807681908736                13                  10    None
# 1716  672614745925664768                 6                  10  pupper
# 377   816697700272001025                12                  10    None
# 1721  672591271085670400                 8                  10    None
# 801   750026558547456000                10                  10    None
# 335   822462944365645825                14                  10  pupper
# 584   782722598790725632                10                  10    None
#
#       img_num               prediction1  prediction1_conf  prediction1_dog  \
# 733         1  Chesapeake Bay retriever          0.480048             True
# 731         1        Labrador retriever          0.778546             True
# 951         2     flat-coated retriever          0.656463             True
# 1611        1                Rottweiler          0.591829             True
# 1716        1                  starfish          0.712717            False
# 377         1                 Chihuahua          0.756992             True
# 1721        1                   gondola          0.134290            False
# 801         1           standard poodle          0.258732             True
# 335         3                Pomeranian          0.960199             True
# 584         1              Irish setter          0.574557             True
#
#            prediction2  prediction2_conf  prediction2_dog  \
# 733             vizsla          0.264522             True
# 731        bathing cap          0.154254            False
# 951         Great Dane          0.084766             True
# 1611          Doberman          0.204544             True
# 1716          goldfish          0.258865            False
# 377         Pomeranian          0.052850             True
# 1721          lifeboat          0.108356            False
# 801              teddy          0.130760            False
# 335            Samoyed          0.023056             True
# 584   golden retriever          0.339251             True
#
#                   prediction3  prediction3_conf  prediction3_dog
# 733                Weimaraner          0.121840             True
# 731          golden retriever          0.024972             True
# 951        Labrador retriever          0.058909             True
# 1611  black-and-tan coonhound          0.078602             True
# 1716             sea cucumber          0.002015            False
# 377               Maltese dog          0.047608             True
# 1721                 bassinet          0.093679            False
# 801                toy poodle          0.071726             True
# 335               Maltese dog          0.008945             True
# 584                 seat belt          0.046108            False

# %% [markdown]
# ### Define

# %% [markdown]
# - correct numerator and denominator values in tweets_data

# %% [markdown]
# ### Code

# %%
for i, record in dog_data.iterrows():
    dog_data.loc[i, "rating_denominator"] = 10
    
    if dog_data.loc[i, "rating_numerator"] > 20:
        dog_data.loc[i, "rating_numerator"] = 20
        
    if dog_data.loc[i, "rating_numerator"] < 10:
        dog_data.loc[i, "rating_numerator"] = 10

# %% [markdown]
# ### Test

# %%
dog_data["rating_denominator"].value_counts()
# Out:
# 10    2075
# Name: rating_denominator, dtype: int64

# %%
dog_data["rating_numerator"].value_counts()
# Out:
# 10    844
# 12    474
# 11    413
# 13    284
# 14     40
# 20     19
# 15      1
# Name: rating_numerator, dtype: int64

# %% [markdown]
# ### Define

# %% [markdown]
# - Remove records with predictions that is not a dog, for prediction1

# %% [markdown]
# ### Code

# %%
# Define a function to remove non-dog predictions
def correct_predictions(df, column_name):
    wrong_predictions = []
    
    predictions = df[column_name].value_counts().to_dict()

    for i in predictions.items():
        if i[1] <= 7:
            wrong_predictions.append(i[0])
            
    for i, record in df.iterrows():
        if df.loc[i, column_name] in wrong_predictions:
            df.drop(i, inplace = True)
            
    return df

# %%
dog_data = correct_predictions(dog_data, "prediction1")

# %%
dog_data = correct_predictions(dog_data, "prediction2")

# %%
dog_data = correct_predictions(dog_data, "prediction3")

# %% [markdown]
# ### Test

# %%
dog_data["prediction1"].value_counts()
# Out:
# golden retriever                  104
# Pembroke                           74
# Labrador retriever                 55
# Chihuahua                          41
# pug                                36
# Samoyed                            26
# malamute                           26
# Pomeranian                         23
# French bulldog                     19
# toy poodle                         18
# Siberian husky                     17
# chow                               17
# Staffordshire bullterrier          16
# Cardigan                           15
# Eskimo dog                         14
# Shetland sheepdog                  13
# seat belt                          13
# German shepherd                    11
# Great Pyrenees                     10
# Border collie                       9
# American Staffordshire terrier      8
# kuvasz                              8
# Pekinese                            8
# Shih-Tzu                            8
# beagle                              8
# cocker spaniel                      7
# Maltese dog                         7
# papillon                            6
# collie                              6
# Boston bull                         6
# Rottweiler                          6
# dalmatian                           6
# dingo                               6
# miniature pinscher                  6
# Norwegian elkhound                  5
# kelpie                              5
# Italian greyhound                   5
# Chesapeake Bay retriever            5
# whippet                             4
# tennis ball                         4
# boxer                               4
# malinois                            4
# standard poodle                     4
# Lakeland terrier                    4
# miniature poodle                    4
# English springer                    3
# basset                              3
# Great Dane                          3
# teddy                               3
# West Highland white terrier         3
# soft-coated wheaten terrier         3
# schipperke                          3
# borzoi                              3
# web site                            2
# Doberman                            2
# doormat                             2
# English setter                      2
# Airedale                            1
# Old English sheepdog                1
# vizsla                              1
# Name: prediction1, dtype: int64

# %%
dog_data["prediction2"].value_counts()
# Out:
# Labrador retriever                63
# Cardigan                          62
# golden retriever                  54
# Siberian husky                    31
# Pomeranian                        29
# French bulldog                    29
# Chihuahua                         27
# Pembroke                          22
# Eskimo dog                        22
# collie                            21
# kuvasz                            19
# Chesapeake Bay retriever          17
# Samoyed                           17
# miniature poodle                  17
# cocker spaniel                    16
# Boston bull                       16
# toy poodle                        16
# American Staffordshire terrier    14
# Pekinese                          12
# beagle                            12
# chow                              12
# toy terrier                       11
# malamute                          11
# malinois                          11
# Italian greyhound                 10
# Great Pyrenees                     9
# Staffordshire bullterrier          9
# miniature pinscher                 9
# pug                                9
# German shepherd                    8
# whippet                            8
# Tibetan mastiff                    8
# Norwegian elkhound                 8
# boxer                              7
# Brabancon griffon                  7
# Lhasa                              7
# bull mastiff                       7
# Irish setter                       7
# Shetland sheepdog                  7
# borzoi                             7
# teddy                              6
# basset                             6
# kelpie                             6
# seat belt                          6
# Border collie                      5
# Shih-Tzu                           4
# Irish terrier                      4
# ice bear                           4
# West Highland white terrier        3
# black-and-tan coonhound            2
# Maltese dog                        2
# Name: prediction2, dtype: int64

# %%
dog_data["prediction3"].value_counts()
# Out:
# Labrador retriever                53
# Chihuahua                         43
# Eskimo dog                        32
# kuvasz                            30
# golden retriever                  27
# kelpie                            26
# Pekinese                          24
# Staffordshire bullterrier         23
# cocker spaniel                    22
# French bulldog                    21
# chow                              21
# malamute                          20
# Great Pyrenees                    20
# Pembroke                          18
# basenji                           18
# Pomeranian                        18
# Cardigan                          17
# American Staffordshire terrier    16
# Boston bull                       15
# bull mastiff                      15
# beagle                            14
# toy terrier                       13
# Chesapeake Bay retriever          13
# Siberian husky                    13
# Saluki                            13
# dingo                             12
# pug                               12
# Shetland sheepdog                 11
# Tibetan mastiff                   11
# boxer                             11
# toy poodle                        11
# bloodhound                        10
# Maltese dog                       10
# standard poodle                   10
# papillon                           9
# Border collie                      9
# doormat                            9
# keeshond                           9
# collie                             9
# Siamese cat                        8
# Tibetan terrier                    8
# German shepherd                    8
# West Highland white terrier        8
# seat belt                          8
# miniature poodle                   8
# Name: prediction3, dtype: int64

# %%
dog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 736 entries, 1 to 2072
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            736 non-null    int64
#  1   rating_numerator    736 non-null    int64
#  2   rating_denominator  736 non-null    int64
#  3   stage               128 non-null    object
#  4   img_num             736 non-null    int64
#  5   prediction1         736 non-null    object
#  6   prediction1_conf    736 non-null    float64
#  7   prediction1_dog     736 non-null    bool
#  8   prediction2         736 non-null    object
#  9   prediction2_conf    736 non-null    float64
#  10  prediction2_dog     736 non-null    bool
#  11  prediction3         736 non-null    object
#  12  prediction3_conf    736 non-null    float64
#  13  prediction3_dog     736 non-null    bool
# dtypes: bool(3), float64(3), int64(4), object(4)
# memory usage: 87.3+ KB

# %%
dog_tweets = tweets_data.merge(dog_data, on = "tweet_id", how = "inner")

# %%
dog_tweets.to_csv("twitter_archive_master.csv")

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Analysis Question:
# - __What is the dogs types with the highest rates?__
# - __What is the dog stage with highest highest rates?__
# - __Does dogs types with highest favourite counts is the same with which has highest rates?__

# %% [markdown]
# __Q1:What is the dogs types with the highest rates?__
# - For this question I will take the predictions with the highest accuracy and get its raitings

# %%
dog_data.describe()
# Out:
#            tweet_id  rating_numerator  rating_denominator     img_num  \
# count  7.360000e+02        736.000000               736.0  736.000000
# mean   7.482580e+17         11.449728                10.0    1.241848
# std    6.888079e+16          1.403659                 0.0    0.611623
# min    6.660334e+17         10.000000                10.0    1.000000
# 25%    6.816355e+17         10.000000                10.0    1.000000
# 50%    7.354523e+17         11.000000                10.0    1.000000
# 75%    8.062250e+17         12.000000                10.0    1.000000
# max    8.921774e+17         20.000000                10.0    4.000000
#
#        prediction1_conf  prediction2_conf  prediction3_conf
# count        736.000000        736.000000        736.000000
# mean           0.659017          0.140173          0.057690
# std            0.246713          0.106887          0.054703
# min            0.107948          0.000059          0.000008
# 25%            0.447652          0.045930          0.009727
# 50%            0.683583          0.127897          0.042427
# 75%            0.887826          0.207808          0.093575
# max            0.999885          0.467678          0.273419

# %% [markdown]
# from this summary, the mean, min, and max predictions confirmations is for prediction 1 so i will use prediction one columns

# %%
# Create Rating Column
dog_data["rating_numerator"].astype(float)
dog_data["rating_numerator"].astype(float)

dog_data["final_rating"] = dog_data["rating_numerator"] / 10.0

# %%
dog_data
# Out:
#                 tweet_id  rating_numerator  rating_denominator  stage  \
# 1     892177421306343426                13                  10   None
# 2     891815181378084864                12                  10   None
# 7     890729181411237888                13                  10   None
# 9     890240255349198849                14                  10  doggo
# 10    890006608113172480                13                  10   None
# ...                  ...               ...                 ...    ...
# 2054  666287406224695296                10                  10   None
# 2055  666273097616637952                11                  10   None
# 2061  666082916733198337                10                  10   None
# 2064  666063827256086533                10                  10   None
# 2072  666033412701032449                10                  10   None
#
#       img_num        prediction1  prediction1_conf  prediction1_dog  \
# 1           1          Chihuahua          0.323581             True
# 2           1          Chihuahua          0.716012             True
# 7           2         Pomeranian          0.566142             True
# 9           1           Pembroke          0.511319             True
# 10          1            Samoyed          0.957979             True
# ...       ...                ...               ...              ...
# 2054        1        Maltese dog          0.857531             True
# 2055        1  Italian greyhound          0.176053             True
# 2061        1                pug          0.489814             True
# 2064        1   golden retriever          0.775930             True
# 2072        1    German shepherd          0.596461             True
#
#           prediction2  prediction2_conf  prediction2_dog         prediction3  \
# 1            Pekinese          0.090647             True            papillon
# 2            malamute          0.078253             True              kelpie
# 7          Eskimo dog          0.178406             True            Pembroke
# 9            Cardigan          0.451038             True           Chihuahua
# 10         Pomeranian          0.013884             True                chow
# ...               ...               ...              ...                 ...
# 2054       toy poodle          0.063064             True    miniature poodle
# 2055      toy terrier          0.111884             True             basenji
# 2061     bull mastiff          0.404722             True      French bulldog
# 2064  Tibetan mastiff          0.093718             True  Labrador retriever
# 2072         malinois          0.138584             True          bloodhound
#
#       prediction3_conf  prediction3_dog  final_rating
# 1             0.068957             True           1.3
# 2             0.031379             True           1.2
# 7             0.076507             True           1.3
# 9             0.029248             True           1.4
# 10            0.008167             True           1.3
# ...                ...              ...           ...
# 2054          0.025581             True           1.0
# 2055          0.111152             True           1.1
# 2061          0.048960             True           1.0
# 2064          0.072427             True           1.0
# 2072          0.116197             True           1.0
#
# [736 rows x 15 columns]

# %%
# Visualize raiting with dog types
base_color = sns.color_palette()[0]
dog_groupedby_type = dog_data.groupby("prediction1").mean()

# %%
# Get the highest 10 types ratings
type_rating = pd.DataFrame(dog_groupedby_type.sort_values("final_rating")["final_rating"][-10:-1]).reset_index()

# %%
type_rating = type_rating.sort_values(by = "final_rating", ascending = False)
type_rating
# Out:
#         prediction1  final_rating
# 8    Great Pyrenees      1.250000
# 7   standard poodle      1.225000
# 6          Pekinese      1.212500
# 5        Eskimo dog      1.207143
# 4    Siberian husky      1.205882
# 1  English springer      1.200000
# 2    cocker spaniel      1.200000
# 3          Doberman      1.200000
# 0  golden retriever      1.190385

# %%
sns.barplot(data = type_rating, x = "final_rating", y = "prediction1", color = base_color)
plt.grid()
plt.title("Top 10 Dog Preeds with highest rates")
plt.show()

# %% [markdown]
# __Q2:What is the dog stage with highest highest rates?__
# - For this question I will take the stage column and get its raitings

# %%
stage_rating = pd.DataFrame(dog_data.groupby("stage").mean().sort_values("final_rating", ascending = False)["final_rating"]).reset_index()
stage_rating
# Out:
#      stage  final_rating
# 0  floofer      1.250000
# 1    doggo      1.196774
# 2    puppo      1.178571
# 3   pupper      1.164198

# %%
sns.barplot(data = stage_rating, x = "final_rating", y = "stage", color = base_color)
plt.grid()
plt.title("Dog Stages Rates")
plt.show()

# %% [markdown]
# __Q3 : Does dogs types with highest favourite counts is the same with which has highest rates?__

# %% [markdown]
# for this question i will create DF with dog preeds, final ratings, and Favourite counts.

# %%
dog_tweets.to_csv()

# %%
dog_groupby_preed = dog_tweets.groupby("prediction1").mean()

# %%
# prepare plots DFs
preeds_ratings = dog_groupby_preed.sort_values("final_rating", ascending = False)[:10].reset_index()
preeds_favourites = dog_groupby_preed.sort_values("favourite_count", ascending = False)[:10].reset_index()

# %%
# Create multiple plots figure
figure, axis = plt.subplots(1, 2)

# plt1 --> Preeds with highest Rates
axis[0].barh(preeds_ratings["prediction1"] , preeds_ratings["final_rating"], color = base_color)
axis[0].set_title("Preeds with highest Rates")
axis[0].grid()

# plt2 --> Preeds with highest Favourites count
axis[1].barh(preeds_favourites["prediction1"], preeds_favourites["favourite_count"], color = base_color)
axis[1].set_title("Preeds with highest Favourites count")
axis[1].grid()

#plt size
plt.rcParams["figure.figsize"] = (20, 10)
plt.rcParams.update({"font.size" : 15})
plt.tight_layout()

plt.show()

# %% [markdown]
# we notice difference in tweets rating of dogs and its favourite counts

# %% [markdown]
# # Report

# %% [markdown]
# ### Report Wrangling efforts

# %% [markdown]
# __Gathering Data process__ <br>
# I have Gathered data from multiple sources<br>
# - Download a file from the internet "twitter-enhanced-archieve.tsv"
# - Download programmatically "prediction.csv"
# - Download API Archieve data using twitter API
#
# __Assesment process__ <br>
# using visual assesment and programmatic assesment techniques generating an assesment report with the data issues
# ### Quality Issues
# ##### Tweets DF
# - Miising Data in __[in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp]__ columns
# - In source column the link is extracted with "a" HTML tag
# - __Name__ column, Mistaken values such as [ single character name "a"]
# - Mistaken values in __[rating_denominator, rating_numerator]__ columns
# - erroneous entry Nu: 1970 has p1 value __laptop__
#
#
# ##### Predictions DF
# - columns names of predictions columns are not descriptive __EX/ P1 --> prediction_01__
# - predictions names are not proper cased, have "_" delimiters
# - erroneous prediction values in __P1, P2, and P3__ columns
# - There is missing records in predections DF
#
# ##### Tweets_api  DF
# - Missing Records
#
#
# ### Tidness Issues
# ##### Tweets DF
# - __Dog stages, Dog names__ Columns are in the same DF with Tweets data
# - Columns that are not Necessary for our analysis such as __[in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp]__ Columns
# - data in the columns __[doggo, floofer, pupper, puppo]
#
#
# ##### Predictions DF
# - Data about predictions and Tweets are in the same DFs
# - repeated _tweet_id_ column
#
# ##### Tweets_api  DF
# - repeated __tweet_id__ column
# <br>
#
# ### Cleaning Process
# Clean __Quality Issues__ and __Tidness Issues__ as
# mentined in the Define - Code - Test framework

# %% [markdown]
# ### Report Analysis and Visualization efforts

# %% [markdown]
# The Analysis process was focus on answering these questions
# ### Analysis Question:
# - __Q1: What is the dogs types with the highest rates?__
# For this question I will take the predictions with the highest accuracy and get its raitings<br>
# Data Frame used __type_rating__ grouped by preeds<br>
# using bar plot to represent the preeds with highest rates<br>
# <br>
# - __Q2: What is the dog stage with highest highest rates?__
# For this question I will take the stage column and get its raitings<br>
# Data Frame used __stage_rating__ grouped by stages<br>
# using bar plot to represent the stages with highest rates<br>
# <br>
# - __Q3: Does dogs types with highest favourite counts is the same with which has highest rates?__
# for this question i will create DF with dog preeds, final ratings, and Favourite counts
# Data Frame used __dog_tweets__ grouped by preeds and sorted in seperated DFs __preeds_rating__ and __preeds_favourite__ <br>
# using bar plot to represent the preeds with highest rates and favourite counts
