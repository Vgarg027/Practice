# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_mov=pd.read_csv('F:/Data analysis/tmdb-movies.csv')

# %%
df_mov.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
df_mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
null_data = df_mov[df_mov.isnull().any(axis=1)]

# %%
null_data.count()
# Out:
# id                      8874
# imdb_id                 8864
# popularity              8874
# budget                  8874
# revenue                 8874
# original_title          8874
# cast                    8798
# homepage                 944
# director                8830
# tagline                 6050
# keywords                7381
# overview                8870
# runtime                 8874
# genres                  8851
# production_companies    7844
# release_date            8874
# vote_count              8874
# vote_average            8874
# release_year            8874
# budget_adj              8874
# revenue_adj             8874
# dtype: int64

# %%
df_mov.shape
# Out:
# (10866, 21)

# %%
df_mov.shape
# Out:
# (10866, 21)

# %% [markdown]
# df_mov.describe()

# %%
df_mov.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df_mov=df_mov.drop(['cast', 'homepage', 'tagline', 'keywords', 'overview', 'imdb_id'], axis=1)

# %%
df_mov.head(1)
# Out:
#        id  popularity     budget     revenue  original_title         director  \
# 0  135397   32.985763  150000000  1513528810  Jurassic World  Colin Trevorrow
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09

# %%
df_mov.shape
# Out:
# (10866, 15)

# %%
df_mov=df_mov.dropna()

# %%
df_mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9807 entries, 0 to 10865
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9807 non-null   int64
#  1   popularity            9807 non-null   float64
#  2   budget                9807 non-null   int64
#  3   revenue               9807 non-null   int64
#  4   original_title        9807 non-null   object
#  5   director              9807 non-null   object
#  6   runtime               9807 non-null   int64
#  7   genres                9807 non-null   object
#  8   production_companies  9807 non-null   object
#  9   release_date          9807 non-null   object
#  10  vote_count            9807 non-null   int64
#  11  vote_average          9807 non-null   float64
#  12  release_year          9807 non-null   int64
#  13  budget_adj            9807 non-null   float64
#  14  revenue_adj           9807 non-null   float64
# ...

# %%
df_mov.hist(figsize=(20,16));

# %%
df_mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9807 entries, 0 to 10865
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9807 non-null   int64
#  1   popularity            9807 non-null   float64
#  2   budget                9807 non-null   int64
#  3   revenue               9807 non-null   int64
#  4   original_title        9807 non-null   object
#  5   director              9807 non-null   object
#  6   runtime               9807 non-null   int64
#  7   genres                9807 non-null   object
#  8   production_companies  9807 non-null   object
#  9   release_date          9807 non-null   object
#  10  vote_count            9807 non-null   int64
#  11  vote_average          9807 non-null   float64
#  12  release_year          9807 non-null   int64
#  13  budget_adj            9807 non-null   float64
#  14  revenue_adj           9807 non-null   float64
# ...

# %%
df_mov
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10861      21    0.080598          0           0
# 10862   20379    0.065543          0           0
# 10863   39768    0.065141          0           0
# 10864   21449    0.064317          0           0
# 10865   22293    0.035919      19000           0
#
#                      original_title            director  runtime  \
# 0                    Jurassic World     Colin Trevorrow      124
# 1                Mad Max: Fury Road       George Miller      120
# 2                         Insurgent    Robert Schwentke      119
# 3      Star Wars: The Force Awakens         J.J. Abrams      136
# ...

# %%
df_mov['budget'] = df_mov['budget'].replace(0,df_mov['budget'].mean())

df_mov['revenue'] = df_mov['revenue'].replace(0,df_mov['revenue'].mean())

# %%
df_mov['genres'] = df_mov['genres'].apply(lambda x: x.split('|')[0])
df_mov['production_companies'] = df_mov['production_companies'].apply(lambda x: x.split('|')[0])

# %%
df_mov
# Out:
#            id  popularity        budget       revenue  \
# 0      135397   32.985763  1.500000e+08  1.513529e+09
# 1       76341   28.419936  1.500000e+08  3.784364e+08
# 2      262500   13.112507  1.100000e+08  2.952382e+08
# 3      140607   11.173104  2.000000e+08  2.068178e+09
# 4      168259    9.335014  1.900000e+08  1.506249e+09
# ...       ...         ...           ...           ...
# 10861      21    0.080598  1.612666e+07  4.407345e+07
# 10862   20379    0.065543  1.612666e+07  4.407345e+07
# 10863   39768    0.065141  1.612666e+07  4.407345e+07
# 10864   21449    0.064317  1.612666e+07  4.407345e+07
# 10865   22293    0.035919  1.900000e+04  4.407345e+07
#
#                      original_title            director  runtime       genres  \
# 0                    Jurassic World     Colin Trevorrow      124       Action
# 1                Mad Max: Fury Road       George Miller      120       Action
# 2                         Insurgent    Robert Schwentke      119    Adventure
# ...

# %%
genres_popularity = df_mov.groupby(['genres'])['popularity'].mean()
print (genres_popularity.index)
# Out:
# Index(['Action', 'Adventure', 'Animation', 'Comedy', 'Crime', 'Documentary',
#        'Drama', 'Family', 'Fantasy', 'Foreign', 'History', 'Horror', 'Music',
#        'Mystery', 'Romance', 'Science Fiction', 'TV Movie', 'Thriller', 'War',
#        'Western'],
#       dtype='object', name='genres')

# %%
plt.subplots(figsize=(20, 6))
plt.bar(genres_popularity.index, genres_popularity)
plt.title('popularity by genre')
plt.xlabel('genre')
plt.ylabel('Popularity');

# %%
# Continue to explore the data to address your additional research
#   questions. Add more headers as needed if you have more questions to
#   investigate.
# Sort movies by revenue in descending order

sorted_revenue_biggest = df_mov.sort_values(by=['revenue'], ascending = False).head(200)
sorted_revenue_biggest.head(1)
# Out:
#          id  popularity       budget       revenue original_title  \
# 1386  19995    9.432768  237000000.0  2.781506e+09         Avatar
#
#            director  runtime  genres     production_companies release_date  \
# 1386  James Cameron      162  Action  Ingenious Film Partners     12/10/09
#
#       vote_count  vote_average  release_year    budget_adj   revenue_adj
# 1386        8458           7.1          2009  2.408869e+08  2.827124e+09

# %%
sorted_revenue_biggest.popularity.hist();

# %%
sorted_revenue_biggest.runtime.hist()
# Out:
# <AxesSubplot:>

# %%
shorter_movies = df_mov.sort_values(by=['runtime'], ascending = False).head(1000)
runtime = shorter_movies['runtime']
popularity = shorter_movies['popularity']

# %%
plt.scatter(runtime,popularity)
