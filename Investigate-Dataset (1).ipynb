# %% [markdown]
# # Project: Investigate a Dataset - TMDB-Movies
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# ## Introduction
# For this dataset pandas, numpy, matplotlib, seaborn and inline(to draw useful graphs) packages can be used.
#
# ### Dataset Description
# This dataset has information related to movie, which include budget, revenue, cast, director, homepage, tagline, release_date, release_year, production_companies and many more.
#
# ### Question(s) for Analysis
# #### In this TMDB-Movies dataset, following questions can be asked:
# - Which Movies are the most popular of all times?
# - Which movies have the highest and lowest budget?
# - Which year has the highest released movies?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# - In this data wrangling process we will do some operations using functions to prepare the data for analysis.
# - The following steps repreasents an important preprocessing techniques that is required on the dataset.

# %% [markdown]
# #### Step one: Reading and Exploring data
# - In this we will read the csv file using pandas pd.read_csv command.
# - The csv file can be uploaded from the jupyter's homepage using upload button and then it can be used here in the workspace.
# - Then to read the heads of the column df.head() function can be used which will also give 5 rows as a result.

# %%
df=pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# #### Step 2: General statistics
# - In this step we will going to find the dimension shape of dataset using df.shape to find the number of columns and rows in dataset.
# - Then we will display general statistical measurements to read overall scope of the dataset using df.describe() such as count,min,max and std deviation.
# - To know datatypes of each variable df.info can be used.

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# #### Step 3: Remove NA and duplicates:
# - This step is important as it affects the analysis process as well as accuracy of the output numbers and in order to do this we need to remove the garbages from the data.
# - We can detect NAN values in each column separately using df.isnull().sum()
# - We can detect duplicates using sum(df.duplicated()) and also drop duplicates using df.drop_duplicates function
# - Date format is confusing in this dataset so it can be changed using pd.to_datetime
# - Also filling missing values with 0 using function df.fillna(0)

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
sum(df.duplicated())
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
# changing the given release date into datetime format
df['release_date']=pd.to_datetime(df['release_date'])
df['release_date'].head()
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# 3   2015-12-15
# 4   2015-04-01
# Name: release_date, dtype: datetime64[ns]

# %%
df.fillna(0)
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %% [markdown]
# #### Step 4: Remove Un-used columns
# - After exploring we get to know which columns are useful in our analysis so we can remove unused columns lie imdb_id, revenue_adj, overview, homepage and tagline.
# - After we calculate profit we may remove revenue and budget column.

# %%
# Removes unused columns that are not needed in the analysis process
df.drop(['imdb_id','revenue_adj','overview','homepage','tagline'],axis=1,inplace=True)
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                                             keywords  runtime  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Research Question 1 Which movies are the most popular of all times?

# %%
df['profit']=df['revenue']-df['budget']

# %%
def minmax(x):
    mins=df[x].idxmin()
    maax=df[x].idxmax()
    high=pd.DataFrame(df.loc[maax,:])
    low=pd.DataFrame(df.loc[mins,:])
    
    print("Movie has the highest "+x+ ":",df['original_title'][maax])
    print("Movie has the lowest "+x+ ":",df['original_title'][mins])
    return pd.concat([high,low],axis=1)

minmax('profit')
# Out:
# Movie has the highest profit: Avatar
# Movie has the lowest profit: The Warrior's Way
#                                                                    1386  \
# id                                                                19995
# imdb_id                                                       tt0499549
# popularity                                                      9.43277
# budget                                                        237000000
# revenue                                                      2781505847
# original_title                                                   Avatar
# cast                  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# homepage                                    http://www.avatarmovie.com/
# director                                                  James Cameron
# tagline                                     Enter the World of Pandora.
# keywords              culture clash|future|space war|space colony|so...
# ...

# %% [markdown]
# - The first column shows the highest profitable movie and second column shows the highest in loss movie of the dataset.
# - Avatar movie directed by james cameron has 7.1 vote average with good tagline.

# %% [markdown]
# ### Research Question 2  Which movies have the highest and lowest budget?

# %%
df['budget']=df['budget']
minmax('budget')
# Out:
# Movie has the highest budget: The Warrior's Way
# Movie has the lowest budget: Mr. Holmes
#                                                                    2244  \
# id                                                                46528
# popularity                                                      0.25054
# budget                                                        425000000
# revenue                                                        11087569
# original_title                                        The Warrior's Way
# cast                  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...
# director                                                     Sngmoo Lee
# keywords              assassin|small town|revenge|deception|super speed
# runtime                                                             100
# genres                        Adventure|Fantasy|Action|Western|Thriller
# production_companies                           Boram Entertainment Inc.
# ...

# %%
info=pd.DataFrame(df['budget'].sort_values(ascending=False))
info['original_title']=df['original_title']
data=list(map(str,(info['original_title'])))

x=list(data[:10])
y=list(info['budget'][:10])

ax=sns.pointplot(y,x)
sns.set(rc={'figure.figsize':(10,5)})
ax.set_title("Top 10 High Budget Movies",fontsize = 15)
ax.set_xlabel("Budget",fontsize = 13)
sns.set_style("darkgrid");
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - The one with highest budget has many casts and different genre which can be cause of more budgeted movie with very less profit.
# - This clearly shows the lowest budget movie and highest budget movie.

# %% [markdown]
# ### Research Question 3 which year has the highest released movie?

# %%
d1=df.groupby('release_year').count()['id']
print(d1.tail())

df.groupby('release_year').count()['id'].plot(xticks=np.arange(1960,2016,5))

sns.set(rc={'figure.figsize':(10,6)})
plt.title("Years vs Number of movies",fontsize=12)
plt.xlabel('Release year',fontsize=10)
plt.ylabel('Number of Movies',fontsize=10)
sns.set_style("whitegrid");
# Out:
# release_year
# 2011    540
# 2012    588
# 2013    659
# 2014    700
# 2015    629
# Name: id, dtype: int64

# %% [markdown]
# - This graph represents the released movie in different year. As there are many years, gap interval of 5 is given so that there is no clutter in graph.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - Revenue is directly connected to Budget.
# - Avatar is the most profitable movie.
# - The warrior's way is the highest budget movie with lowest profit.
# - Year 2014 has the highest released movies of all the years.
# - Mr. Holmes is the movie with lowest budget and still it gets some profit.

# %% [markdown]
# ## Limitations

# %% [markdown]
# - During exploratory analysis, there were many questions that we can still answer but due to unavailability of some values it can't happened
